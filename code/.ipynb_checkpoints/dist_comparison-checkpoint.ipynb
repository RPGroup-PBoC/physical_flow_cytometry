# %% [markdown]
# # Moment Comparison Between Microscopy & Flow Cytometry

# %%
import numpy as np
import pandas as pd
import glob
import mwc_induction_utils as mwc
import scipy.stats
import pymc3 as pm 
import theano.tensor as tt
import corner
from tqdm import tqdm
import scipy.optimize

import seaborn as sns
import matplotlib.pyplot as plt
import bokeh.io
import bokeh.plotting
import bokeh.layouts
np.random.seed(42)
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2d6d20e5-68c7-494c-88a9-91760a089982">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ##  Comparison of distributions

# %%
# Load the microscopy data set.
mic_files = glob.glob('../data/microscopy/*O2*microscopy*.csv')
mic_df = pd.concat([pd.read_csv(f, comment='#') for f in mic_files])

# Only keep RBS1027 for the purposes of this comparison.
mic_df = mic_df[mic_df['rbs']=='RBS1027']

# Load the flow data sets.
flow_files = glob.glob('../data/flow/*O2*IPTG.csv')
flow_df = []
alpha = 0.4
for i, file in enumerate(flow_files):
    # Load the data set and gate
    _df = pd.read_csv(file, comment='#')
    gated = mwc.auto_gauss_gate(_df, alpha=alpha)
    
    # Get the string of the concentration. 
    name_split = file.split('_')
    conc = float(name_split[-1].split('uM')[0])
    date = name_split[0].split('/')[-1]
    operator = name_split[2]
    rbs = name_split[3]
    _df = _df.loc[:, ['FITC-A', 'FSC-A', 'SSC-A']]
    _df.insert(0, 'rbs', rbs)
    _df.insert(0, 'operator', operator)
    _df.insert(0, 'IPTG_uM', conc)
    _df.insert(0, 'date', date)
    flow_df.append(_df)
    
flow_df = pd.concat(flow_df, axis=0)

# %%
def ecdf(data):
    return np.sort(data), np.arange(0, len(data)) / len(data)

# %%
plot_kwargs = {'plot_width':500, 'plot_height':300}
p1 = mwc.bokeh_boiler(**plot_kwargs)
p2 = mwc.bokeh_boiler(**plot_kwargs)
grouped = mic_df.groupby('IPTG_uM')
colors = sns.color_palette('Blues_r', n_colors=20)
colors = colors.as_hex()
i = 0 
for g, d_mic in grouped: 
    x, y = ecdf(d_mic['mean_intensity'])
    p1.line(np.log10(x), y, line_width=2.5, color=colors[i],
            alpha=0.75) 
    i += 1  
    
grouped = flow_df.groupby('IPTG_uM')
i = 0
for g, d_flow in grouped:
    x, y = ecdf(d_flow['FITC-A'])
    p2.line(np.log10(x), y, line_width=2.5, color=colors[i])
    i += 1
p1.xaxis.axis_label = 'log mean pixel intensity (a.u.)'
p1.yaxis.axis_label = 'ECDF'
p1.title.text = 'distributions from microscopy'

p2.xaxis.axis_label='log mean object intensity'
p2.title.text = 'distributions from flow cytometry'

row = bokeh.layouts.row(p1, p2)
# bokeh.io.show(row)

# %% [markdown]
# To compare the distributions between the two methods, we can look at the **[central moments]()**, which provides information on the shape of the distribution rather than just the location. We can mathematically describe the $k-$th central moment of a data set as
#
# $$
# m_k = {1 \over n}\sum\limits_i^n(x_i - \bar{x})^k,
# $$
#
# where $m_k$ is the $k-$th moment, $x_i$ is the $i$-th data point in the data set, and $\bar{x}$ is the mean.

# %%
p = mwc.bokeh_boiler(**{'plot_width': 500, 'plot_height': 300, 'y_axis_type':'log'})

moments = [2, 3, 4, 5, 6, 7]

flow_dup_files = glob.glob('../data/5000uM_IPTG_distributions/*IPTG.csv')
for f in flow_dup_files:
    d_flow = pd.read_csv(f, comment='#')
    gated = mwc.auto_gauss_gate(d_flow, alpha=0.4)
    for m in moments:
#     _mic_moment = scipy.stats.moment(d_mic['mean_intensity'], moment=m) 
        _flow_moment = scipy.stats.moment(gated['FITC-A'], moment=m) 
#     p.circle(m, _mic_moment, size=10, legend='microscopy', color='dodgerblue')
        p.circle(m, _flow_moment, size=5, legend='flow cytometry', color='tomato',
                alpha=0.5)
    
mic_dup_files = glob.glob('../data/5000uM_IPTG_distributions/*microscopy*.csv')
for f in mic_dup_files:
    d_mic = pd.read_csv(f, comment='#')
    d_mic = d_mic[d_mic['IPTG_uM']==5000]
    for m in moments:
        _mic_moment = scipy.stats.moment(d_mic['mean_intensity'], moment=m)
        p.circle(m, _mic_moment, size=5, legend='microscopy', color='dodgerblue',
                alpha=0.5)
    
p.xaxis.axis_label = 'central moment order'
p.yaxis.axis_label = 'log central moment value'
p.legend.location = 'top_left'
p.legend.background_fill_color = '#E3DCD0'
p.legend.border_line_color = '#FFFFFF'
bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9df67b2e-015c-4bd9-9ce5-e7a2f4a15304"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9df67b2e-015c-4bd9-9ce5-e7a2f4a15304");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9df67b2e-015c-4bd9-9ce5-e7a2f4a15304");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9df67b2e-015c-4bd9-9ce5-e7a2f4a15304' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"76158422-3a0e-4b6c-9d97-e93db0e546ef":{"roots":{"references":[{"attributes":{"callback":null,"data":{}},"id":"ef0f65a5-8ae7-4dbd-b53c-60807f5a96c2","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"dodgerblue"},"line_alpha":{"value":0.5},"line_color":{"value":"dodgerblue"},"size":{"units":"screen","value":5},"x":{"value":6},"y":{"value":1.0886615349304937e+18}},"id":"808b9c13-816a-4341-8435-f710ec1986a2","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"dodgerblue"},"line_alpha":{"value":0.5},"line_color":{"value":"dodgerblue"},"size":{"units":"screen","value":5},"x":{"value":6},"y":{"value":7.836445410165182e+16}},"id":"3f59582e-16f0-4f26-b61c-980721d26d82","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"value":6},"y":{"value":7.836445410165182e+16}},"id":"20ffd534-f99c-46dd-a45c-2e18e04c4de0","type":"Circle"},{"attributes":{"data_source":{"id":"ef0f65a5-8ae7-4dbd-b53c-60807f5a96c2","type":"ColumnDataSource"},"glyph":{"id":"3f59582e-16f0-4f26-b61c-980721d26d82","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"20ffd534-f99c-46dd-a45c-2e18e04c4de0","type":"Circle"},"selection_glyph":null},"id":"12958caa-57e2-4f9c-b7b0-0ff30685be7a","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"value":6},"y":{"value":1.0886615349304937e+18}},"id":"79a5f0ba-a90d-4672-86fc-03119bf2da3a","type":"Circle"},{"attributes":{"callback":null,"data":{}},"id":"9cfb2157-c663-42ff-a734-3ab3e7bfa157","type":"ColumnDataSource"},{"attributes":{"callback":null,"data":{}},"id":"368ab422-b45f-461f-af28-5d57ce8e98c1","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"dodgerblue"},"line_alpha":{"value":0.5},"line_color":{"value":"dodgerblue"},"size":{"units":"screen","value":5},"x":{"value":7},"y":{"value":7.40377753339869e+19}},"id":"9b8c78a7-ae52-4e7b-8177-ebd9e7b315f7","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"value":7},"y":{"value":7.40377753339869e+19}},"id":"199905d5-be14-4832-b730-e6df5b2d23ed","type":"Circle"},{"attributes":{"data_source":{"id":"9cfb2157-c663-42ff-a734-3ab3e7bfa157","type":"ColumnDataSource"},"glyph":{"id":"9b8c78a7-ae52-4e7b-8177-ebd9e7b315f7","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"199905d5-be14-4832-b730-e6df5b2d23ed","type":"Circle"},"selection_glyph":null},"id":"e41ad900-b59d-435b-a1d4-256a4e7a38d5","type":"GlyphRenderer"},{"attributes":{"callback":null,"data":{}},"id":"0078eb7c-caa5-4dc2-a515-0f98e3aebbc0","type":"ColumnDataSource"},{"attributes":{"callback":null,"data":{}},"id":"f6c16b99-ad04-4d90-8576-990eb1cb741b","type":"ColumnDataSource"},{"attributes":{"callback":null,"data":{}},"id":"6518079d-f123-4ee5-b17a-998d5da146a7","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"6518079d-f123-4ee5-b17a-998d5da146a7","type":"ColumnDataSource"},"glyph":{"id":"98b1dddf-b98d-4eaf-b731-957e32e8e618","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e28f695b-9253-4223-9bbb-c908a9390cdc","type":"Circle"},"selection_glyph":null},"id":"c810acc0-62ed-4d06-98c2-e39fc8a63821","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"82020189-5833-4c51-9dcd-d64b9c2a4da9","type":"ColumnDataSource"},"glyph":{"id":"9ce1e119-cce9-4dab-9c97-988db38c5399","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9867748f-57a2-493e-a8c1-a2b8b2c386d5","type":"Circle"},"selection_glyph":null},"id":"f66d697c-8fb7-48ff-8bb3-c51f ...

# %% [markdown]
# ## Parameter estimation using population means

# %%
# Randomly choose three days. 
flow_master = pd.read_csv('../data/flow_master.csv', comment='#')
O2_flow = flow_master[((flow_master['operator']=='O2') |
                      (flow_master['operator']=='O1')) &
                      (flow_master['rbs']=='RBS1027')]
# dates = O2_flow['date'].unique()
# chosen_dates = np.random.choice(dates, 3)                   
# O2_flow = O2_flow[(O2_flow['date']== chosen_dates[0]) |
#                  (O2_flow['date']== chosen_dates[1]) |
#                  (O2_flow['date']== chosen_dates[2])]

p = mwc.bokeh_boiler(**{'plot_width': 500, 'plot_height':300,
                        'x_axis_type':'log', 'x_axis_label':'[IPTG] (µM)',
                       'y_axis_label':'fold-change'})

grouped = O2_flow.groupby('IPTG_uM')['fold_change_A'].mean()
IPTG = O2_flow['IPTG_uM'].unique() / 1E6
p.circle(O2_flow['IPTG_uM'] / 1E6, O2_flow['fold_change_A'], size=5,
        color='dodgerblue')
# p.circle(IPTG, grouped, size=7, color='dodgerblue')


# Microscopy. 
mic_master = pd.read_csv('../data/microscopy_master.csv', comment='#')
O2_mic = mic_master[((mic_master['operator']=='O2') | (mic_master['operator'] == 'O1')) &\
                    (mic_master['rbs']=='RBS1027')]
grouped = O2_mic.groupby('IPTG_uM')['fold_change'].mean()
# p.circle(IPTG, grouped, color='tomato')
p.circle(O2_mic['IPTG_uM']/1E6, O2_mic['fold_change'], color='tomato')

bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9a580b3d-f40e-4e83-81dc-e4aa05bd4301"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9a580b3d-f40e-4e83-81dc-e4aa05bd4301");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9a580b3d-f40e-4e83-81dc-e4aa05bd4301");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9a580b3d-f40e-4e83-81dc-e4aa05bd4301' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0f6e3940-4aef-4273-8f4f-f8d2a6902d68":{"roots":{"references":[{"attributes":{"data_source":{"id":"9dc97259-6a2d-4ed8-96a1-5b1f0d5c2755","type":"ColumnDataSource"},"glyph":{"id":"30cefb53-6dff-478a-ba2f-4b8c6f17ca89","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"156b1a09-fa59-4e50-b9bd-9f1c3621c810","type":"Circle"},"selection_glyph":null},"id":"24c555c9-d5a2-4670-a1f4-9215b86c281d","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"52d7ae86-7dd7-4b85-8f45-aebb0761de93","type":"ColumnDataSource"},"glyph":{"id":"f110aa62-72fc-4f17-853b-26172570d9f2","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"342261d2-15c7-458d-a9ed-6ed22fdc822e","type":"Circle"},"selection_glyph":null},"id":"5eda9537-c60d-4ade-a1ad-a6089d9fe26f","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"dodgerblue"},"line_color":{"value":"dodgerblue"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"30cefb53-6dff-478a-ba2f-4b8c6f17ca89","type":"Circle"},{"attributes":{"overlay":{"id":"54eb5dd8-a4b2-48cb-8825-7a189f8f7807","type":"BoxAnnotation"},"plot":{"id":"fdf7f0b7-6877-4523-b7f9-ce3acce895da","subtype":"Figure","type":"Plot"}},"id":"5757a100-07dd-4282-8ae3-a6bdea630f4b","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[71]},"y":{"__ndarray__":"...","dtype":"float64","shape":[71]}}},"id":"52d7ae86-7dd7-4b85-8f45-aebb0761de93","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"89a8ac65-e8b7-4131-bfbc-19aac475c41c","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"156b1a09-fa59-4e50-b9bd-9f1c3621c810","type":"Circle"},{"attributes":{"num_minor_ticks":10},"id":"fae3d624-9d1f-4d15-a36a-2f097cffd949","type":"LogTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"02982af4-beec-434a-811a-7fff2fb2b7cc","type":"PanTool"},{"id":"29827a8c-7e70-44ac-9d76-39f5c891527b","type":"WheelZoomTool"},{"id":"5757a100-07dd-4282-8ae3-a6bdea630f4b","type":"BoxZoomTool"},{"id":"75a4d332-3f9a-4413-97f2-f15016069271","type":"SaveTool"},{"id":"495f491b-047c-4b2a-b002-4b7d16bf182e","type":"ResetTool"},{"id":"cae9a83d-af97-41b1-9438-c5843e65e453","type":"HelpTool"}]},"id":"468d4e5c-e78f-4310-bc61-be9c249df2d8","type":"Toolbar"},{"attributes":{"callback":null},"id":"950e01c0-fc1c-4cbe-a512-d0f96513c53b","type":"DataRange1d"},{"attributes":{},"id":"2933b778-6605-4f25-96a6-69d1d2b4ddf8","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"54eb5dd8-a4b2-48cb-8825-7a189f8f7807","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"fdf7f0b7-6877-4523-b7f9-ce3acce895da","subtype":"Figure","type":"Plot"}},"id":"75a4d332-3f9a-4413-97f2-f15016069271","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"86b9d071-6b8e-4a78-8110-40deeba107a9","type":"Title"},{"attributes":{"background_fill_color":{"value":"#E3DCD0"},"below":[{"id":"d0ac570d-7f86-4672-9307-5eefd3a4a51d","type":"LogAxis"}],"left":[{"id":"b3d14506-9a91-4cbe-b8db-237aedca39f0","type":"LinearAxis"}],"plot_height":300,"plot_width":500,"renderers":[{"id":"d0ac570d-7f86-4672-9307-5eefd3a4a51d","type":"LogAxis"},{"id":"cf0efb74-f73a-4fd9-9e8d-b01da19c3fa1","type":"Grid"},{"id":"b3d14506-9a91-4cbe-b8db-237aedca39f0","type":"LinearAxis"},{"id":"32f7372c-805e-486b-8a9b-1d7bbcfa65d9","type":"Grid"},{"id":"54eb5dd8-a4b2-48cb-8825-7a189f8f7807","type":"BoxAnnotation"},{"id": ...

# %%
# Compare the hpd of the values. 
R = 260  # Number of repressor molecules
ep_r = -13.9 #Binding energy of repressor to the DNA
ep_ai = 4.5  # Energetic difference between allosteric states
fixed_params = [R, ep_r, ep_ai]

# Set up the model and define the priors. 
def jeffreys(val):
    return -tt.log(val)

def traceframe(trace, model):
    df = pm.trace_to_dataframe(trace)
    lnprob = []
    for t in tqdm(trace):
        lnprob.append(model.logp(t))
    df.insert(np.shape(df)[1], 'lnprob', lnprob)        
    return df

# %%
flow_model = pm.Model()
mic_model = pm.Model()
models = [flow_model, mic_model]
methods = ['flow cytometry', 'microscopy']
model_df = [O2_flow, O2_mic]
N_ns = 4.6E6

ep_r = -13.9
dfs = []
for i, m in enumerate(models):
    IPTG = model_df[i]['IPTG_uM'].values
    if i == 0:
        fc_obs = model_df[i]['fold_change_A'].values
    else:
        fc_obs = model_df[i]['fold_change'].values
    
    with m:
        ep_a = pm.Uniform('ep_a', lower=-10, upper=10, testval=5)
        ep_i = pm.Uniform('ep_i', lower=-10, upper=10, testval=-0.5)
        sigma = pm.HalfNormal('sigma', sd=1)
#         sigma = pm.DensityDist('sigma', jeffreys, testval=1)

        p_act = (1 + IPTG * np.exp(-ep_a))**2 / ((1 + IPTG * np.exp(-ep_a))**2 +\
            np.exp(-ep_ai) * (1 + IPTG * np.exp(-ep_i))**2)
        fc_theo = (1 + p_act * (2 * model_df[i]['repressors'] / N_ns) * np.exp(-model_df[i]['binding_energy']))**-1
        like = pm.Normal('likelihood',mu=fc_theo, sd=np.sqrt(sigma), observed=fc_obs)
        
        # Find the map. 
        _MAP = pm.find_MAP(model=m, fmin=scipy.optimize.fmin_powell)
        trace = pm.sample(start=_MAP, draws=10000, tune=10000)
        
    df = traceframe(trace, model=m)
#     df.insert(0, 'method', methods[i])
    dfs.append(df)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi...
# Optimization terminated successfully.
#          Current function value: -380.438966
#          Iterations: 3
#          Function evaluations: 124
# Average ELBO = 369.29: 100%|██████████| 200000/200000 [00:18<00:00, 11021.77it/s]
# Finished [100%]: Average ELBO = 369.29
# 100%|██████████| 10000/10000 [00:15<00:00, 654.10it/s]
# 100%|██████████| 10000/10000 [00:00<00:00, 11210.42it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi...
# Optimization terminated successfully.
#          Current function value: -68.357939
#          Iterations: 4
#          Function evaluations: 171
# Average ELBO = 60.011: 100%|██████████| 200000/200000 [00:17<00:00, 11748.44it/s]
# Finished [100%]: Average ELBO = 60.023
# 100%|██████████| 10000/10000 [00:15<00:00, 660.07it/s]
# 100%|██████████| 10000/10000 [00:00<00:00, 11255.79it/s]

# %%
p = mwc.bokeh_boiler()

colors = ['dodgerblue', 'tomato']
for i, d in enumerate(dfs):
    x, y = ecdf(d['ep_a'])
    p.line(x,y, color=colors[i], line_width=2)

bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c830c318-8398-4924-a43a-62a4da8f2ff1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c830c318-8398-4924-a43a-62a4da8f2ff1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c830c318-8398-4924-a43a-62a4da8f2ff1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c830c318-8398-4924-a43a-62a4da8f2ff1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"01ab451f-1fac-4153-88d9-80955e4c755f":{"roots":{"references":[{"attributes":{"dimension":1,"grid_line_color":{"value":"#FFFFFF"},"grid_line_dash":[2,4],"grid_line_width":{"value":2},"plot":{"id":"be696763-ef8a-4170-8a5d-02235f5700da","subtype":"Figure","type":"Plot"},"ticker":{"id":"bcc4b7fa-e038-4002-bd24-95cbb4e4645f","type":"BasicTicker"}},"id":"4bd90c59-50cd-4cb1-93a8-89d5df75813d","type":"Grid"},{"attributes":{"data_source":{"id":"7985ecd6-88dd-4e8a-bc8f-b1c12d5741fc","type":"ColumnDataSource"},"glyph":{"id":"48b0ad15-41b8-482f-81ca-4d139f35c09b","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a1cbf708-ab99-4400-81ad-a7c8960fafe4","type":"Line"},"selection_glyph":null},"id":"cd11a23d-53af-4126-95c2-a18b74a37f71","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"19465a96-8e98-44a1-b071-9ebafddeb8db","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"be696763-ef8a-4170-8a5d-02235f5700da","subtype":"Figure","type":"Plot"}},"id":"f848e33e-4c50-4f67-84e1-eba20016ae3e","type":"PanTool"},{"attributes":{"plot":{"id":"be696763-ef8a-4170-8a5d-02235f5700da","subtype":"Figure","type":"Plot"}},"id":"392f46e8-3373-422b-9966-a4d024a38099","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"19465a96-8e98-44a1-b071-9ebafddeb8db","type":"BoxAnnotation"},"plot":{"id":"be696763-ef8a-4170-8a5d-02235f5700da","subtype":"Figure","type":"Plot"}},"id":"68cf3455-484b-4088-a469-0a53a14a35e8","type":"BoxZoomTool"},{"attributes":{},"id":"e5f02750-2b90-4f78-9787-3a0cb755d468","type":"BasicTicker"},{"attributes":{"plot":{"id":"be696763-ef8a-4170-8a5d-02235f5700da","subtype":"Figure","type":"Plot"}},"id":"72ccc83e-4240-4149-8d8b-007450166fe9","type":"SaveTool"},{"attributes":{"plot":{"id":"be696763-ef8a-4170-8a5d-02235f5700da","subtype":"Figure","type":"Plot"}},"id":"84a44cf5-93a7-4a5f-9016-4c6dc162c42d","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[10000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[10000]}}},"id":"dcb9d35f-f2d5-4362-9d33-360d72f27ddc","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"be696763-ef8a-4170-8a5d-02235f5700da","subtype":"Figure","type":"Plot"}},"id":"6e22f19f-8cb0-4385-b622-94afc23e1cc5","type":"HelpTool"},{"attributes":{},"id":"c4d7d428-a19e-4579-95a7-c9f292015626","type":"BasicTickFormatter"},{"attributes":{"background_fill_color":{"value":"#E3DCD0"},"below":[{"id":"f4d4bb81-b9dc-4358-ac5c-2ba435e827ad","type":"LinearAxis"}],"left":[{"id":"bf245494-0c50-4282-a5bf-97405ac1ba47","type":"LinearAxis"}],"renderers":[{"id":"f4d4bb81-b9dc-4358-ac5c-2ba435e827ad","type":"LinearAxis"},{"id":"b4807d60-6ad1-4a22-b751-639c7a62e72d","type":"Grid"},{"id":"bf245494-0c50-4282-a5bf-97405ac1ba47","type":"LinearAxis"},{"id":"4bd90c59-50cd-4cb1-93a8-89d5df75813d","type":"Grid"},{"id":"19465a96-8e98-44a1-b071-9ebafddeb8db","type":"BoxAnnotation"},{"id":"c1b4d36b-73c1-41f0-aaae-a5ebb2c15b92","type":"GlyphRenderer"},{"id":"cd11a23d-53af-4126-95c2-a18b74a37f71","type":"GlyphRenderer"}],"title":{"id":"2023da2d-8a8e-4604-b889-5f5b000dd0a5","type":"Title"},"tool_events":{"id":"8b18cbfc-9a86-4537-a2d7-394c2c2f3da7","type":"ToolEvents"},"toolbar":{"id":"c8c254b4-d8f1-42e6-8aa8-909bba48b0d1","type":"Toolbar"},"x_range":{"id":"4f1bcc48-f891-4a09-a273-33273869b543","type":"DataRange1d"},"y_range":{"id":"0bcbeaa2-ea35-46eb-b5cd-6b1662603041","type":"DataRange1d"}},"id":"be696763-ef8a-4170-8a5d-02235f5700da","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"94826ceb-7587-471c-b1ca-05b1e9443b48","type":"BasicTickFormatter"},{"attributes":{},"id":"8b18cbfc-9a86-4537-a2d7-394c2c2f3da7","ty ...

# %%
bin_min = np.min([np.min(dfs[0].ep_i), np.min(dfs[1].ep_i)])
bin_max = np.max([np.max(dfs[0].ep_i), np.max(dfs[1].ep_i)])
bins = np.linspace(np.exp(bin_min), np.exp(bin_max), 65)
flow_y, flow_x = np.histogram(np.exp(dfs[0].ep_i), bins=bins)
mic_y, mic_x = np.histogram(np.exp(dfs[1].ep_i), bins=bins)

p1 = mwc.bokeh_boiler()
p2 = mwc.bokeh_boiler()
p3 = mwc.bokeh_boiler()


colors = ['slategray', 'skyblue']
methods = ['flow cytometry', 'microscopy']
for i, d in enumerate(dfs):
    # Compute the ecdf. 
    ka_x, ka_y = ecdf(np.exp(d['ep_a']))
    ki_x, ki_y = ecdf(np.exp(d['ep_i']))
    p2.line(ka_x, ka_y, line_width=2, color=colors[i]) 
    p3.line(ki_x, ki_y, line_width=2, color=colors[i])
 


p1.quad(top=mic_y/np.sum(mic_y), bottom=0, left=mic_x[:-1], right=mic_x[1:], color='skyblue',
      alpha=0.8)
p1.quad(top=flow_y/np.sum(flow_y), bottom=0, left=flow_x[:-1], right=flow_x[1:], color='slategray',
      alpha=0.5)

ell = bokeh.layouts.layout([[p1, p2], [p3]], sizing_mode='stretch_both')
# bokeh.io.show(ell)
# bokeh.io.export_png(ell, filename='test.png')
# bokeh.io.show(p2)

# %%
bin_min = np.min([np.min(dfs[0].ep_i), np.min(dfs[1].ep_i)])
bin_max = np.max([np.max(dfs[0].ep_i), np.max(dfs[1].ep_i)])
bins = np.linspace(np.exp(bin_min), np.exp(bin_max), 65)
flow_y, flow_x = np.histogram(np.exp(dfs[0].ep_i), bins=bins)
mic_y, mic_x = np.histogram(np.exp(dfs[1].ep_i), bins=bins)

p1 = mwc.bokeh_boiler()
p2 = mwc.bokeh_boiler()
p3 = mwc.bokeh_boiler()


colors = ['slategray', 'skyblue']
methods = ['flow cytometry', 'microscopy']
for i, d in enumerate(dfs):
    # Compute the ecdf. 
    ka_x, ka_y = ecdf(np.exp(d['ep_a']))
    ki_x, ki_y = ecdf(np.exp(d['ep_i']))
    p2.line(ka_x, ka_y, line_width=2, color=colors[i]) 
    p3.line(ki_x, ki_y, line_width=2, color=colors[i])
 


p1.quad(top=mic_y/np.sum(mic_y), bottom=0, left=mic_x[:-1], right=mic_x[1:], color='skyblue',
      alpha=0.8)
p1.quad(top=flow_y/np.sum(flow_y), bottom=0, left=flow_x[:-1], right=flow_x[1:], color='slategray',
      alpha=0.5)

ell = bokeh.layouts.layout([[p1, p2], [p3]], sizing_mode='stretch_both')
# bokeh.io.show(ell)
# bokeh.io.export_png(ell, filename='test.png')
bokeh.io.show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="652582c7-ce77-4bad-8ab5-1ed00015ffb1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("652582c7-ce77-4bad-8ab5-1ed00015ffb1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("652582c7-ce77-4bad-8ab5-1ed00015ffb1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '652582c7-ce77-4bad-8ab5-1ed00015ffb1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"89cf23d6-c46b-48e9-ac11-2f705d414f49":{"roots":{"references":[{"attributes":{"callback":null},"id":"d7fbf072-d729-490d-abbd-b5ed0c11a971","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"dc398c9f-c5ba-4c5c-ad0d-0492a8a20617","type":"PanTool"},{"id":"6799d91e-8bf6-4213-888a-0c1ed1c04417","type":"WheelZoomTool"},{"id":"d5b577dc-cf9c-4e7e-b5af-a5463fe9456a","type":"BoxZoomTool"},{"id":"bfe08a10-7dc4-4a32-8c05-54a14a042d3f","type":"SaveTool"},{"id":"b0169e76-c135-44f2-a0e6-01b543af3636","type":"ResetTool"},{"id":"79adcc4e-4104-40c6-8803-15ddd59dca37","type":"HelpTool"}]},"id":"43bc44e6-cc18-4c48-9ef5-12dad99be8ce","type":"Toolbar"},{"attributes":{},"id":"9ef53289-d29a-4cd7-ac27-4919a996a9f9","type":"ToolEvents"},{"attributes":{"line_color":{"value":"slategray"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"ab39a05b-af23-48f4-80ce-541ac0f3e5a3","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[10000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[10000]}}},"id":"89903762-2b30-479f-a28f-d3a32e60bd86","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"89903762-2b30-479f-a28f-d3a32e60bd86","type":"ColumnDataSource"},"glyph":{"id":"ab39a05b-af23-48f4-80ce-541ac0f3e5a3","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"19270546-178c-40f2-a5af-8d533454ca0b","type":"Line"},"selection_glyph":null},"id":"910a6450-6a01-41eb-8e40-1f340bb790df","type":"GlyphRenderer"},{"attributes":{"axis_label_standoff":3,"axis_label_text_color":{"value":"#3c3c3c"},"axis_label_text_font":"Lucida Sans Unicode","axis_label_text_font_size":{"value":"13pt"},"axis_label_text_font_style":"normal","axis_line_color":{"value":null},"formatter":{"id":"07021114-9069-4b17-b414-0561c5638da3","type":"BasicTickFormatter"},"major_label_text_font":"Lucida Sans Unicode","major_label_text_font_size":{"value":"10pt"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"fa57ed1d-b793-42b3-947f-9de7c5791ee1","subtype":"Figure","type":"Plot"},"ticker":{"id":"ba9e764f-3c98-4377-a9f9-e027db82c086","type":"BasicTicker"}},"id":"41777432-787c-4cc2-8164-ca6f0942aa91","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[10000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[10000]}}},"id":"37454406-a83d-4493-9d3c-c59c3763db53","type":"ColumnDataSource"},{"attributes":{},"id":"70abffe8-c92a-41f3-ac8a-d6406c9988be","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"438e2790-5f18-4702-b9ae-8b165e20d577","type":"DataRange1d"},{"attributes":{},"id":"ba9e764f-3c98-4377-a9f9-e027db82c086","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"09d513a2-9f35-40e7-a776-8e8352451db4","type":"Title"},{"attributes":{"grid_line_color":{"value":"#FFFFFF"},"grid_line_dash":[2,4],"grid_line_width":{"value":2},"plot":{"id":"fa57ed1d-b793-42b3-947f-9de7c5791ee1","subtype":"Figure","type":"Plot"},"ticker":{"id":"ba9e764f-3c98-4377-a9f9-e027db82c086","type":"BasicTicker"}},"id":"ec828164-69c3-45f7-a34e-ce0da1dc14a0","type":"Grid"},{"attributes":{},"id":"07021114-9069-4b17-b414-0561c5638da3","type":"BasicTickFormatter"},{"attributes":{"axis_label_standoff":3,"axis_label_text_color":{"value":"#3c3c3c"},"axis_label_text_font":"Lucida Sans Unicode","axis_label_text_font_size":{"value":"13pt"},"axis_label_text_font_style":"normal","axis_line_color":{"value":null},"formatter":{"id":"70abffe8-c92a-41f3-ac8a-d6406c9988be","type":"BasicTickFormatter"},"major_label_text_font":"Lucida Sans Unicode","major_label_text_font_size":{"value":"10pt"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"fa57ed1d-b793-42b3-947f-9de7c5791ee1","subtype":"Figure","type":"Plot"},"ticker":{"id":"5c ...
